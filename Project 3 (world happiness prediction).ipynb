# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('World happiness')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# No null values are there.

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [raw]
# There are not much outliers or skewness there as there is not much difference between 50th percentile and mean as well as
# between 75th percentile and max point.

# %% [markdown]
# # Visualisation

# %%
cor=df.corr()

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %% [raw]
# As we can see except standard error every factor put a positive impact on happiness score.

# %%
df.plot.scatter(x='Happiness Score',y='Economy (GDP per Capita)')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
df.plot.scatter(x='Happiness Score',y='Family')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Family'>

# %%
df.plot.scatter(x='Happiness Score',y='Health (Life Expectancy)')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %%
df.plot.scatter(x='Happiness Score',y='Freedom')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Freedom'>

# %%
df.drop(['Happiness Rank', 'Country','Dystopia Residual', 'Region','Standard Error'],axis=1,inplace=True)

# %%
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
print(x)
print(y)
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
x=pd.DataFrame(mm.fit_transform(x),columns=x.columns)
x
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    0.826132  0.962403                  0.918244  0.993789
# 1                    0.770412  1.000000                  0.924496  0.938841
# 2                    0.784113  0.970297                  0.853099  0.969615
# 3                    0.863099  0.949167                  0.863409  1.000000
# 4                    0.784592  0.943219                  0.883326  0.945112
# ..                        ...       ...                       ...       ...
# 153                  0.131376  0.551764                  0.418083  0.883953
# 154                  0.169573  0.252355                  0.311241  0.723426
# 155                  0.392329  0.338668                  0.704150  0.234184
# 156                  0.009051  0.296578                  0.218444  0.176937
# 157                  0.123449  0.099805                  0.277425  0.544294
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# # splitting and modeling data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([4.77778874, 6.45268507, 4.61351669, 3.06301906, 4.95909844,
#        5.90862756, 4.22414977, 5.15434891, 4.89585019, 4.67880823,
#        6.69502255, 5.65704649, 5.8774688 , 5.79096669, 6.07500941,
#        5.99396917, 4.12020656, 4.8984179 , 4.05723349, 6.16665281,
#        4.31578402, 6.64429006, 6.76735042, 7.0609662 , 6.29406896,
#        5.43790637, 4.90437801, 4.05992832, 4.35660478, 3.87496992,
#        4.49435623, 5.28106865, 4.35463298, 5.52956953, 4.65688195,
#        4.62418037, 3.75882228, 5.51698473, 5.2696685 , 4.38685155])

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print(r2_score(y_test,pred))
# Out:
# 0.22987311797590748
# 0.4016455499083541
# 0.8272769985165612

# %% [markdown]
# # predictive model

# %%
t=np.array([1.39651,1.24951,0.94143,0.56557,0.31978,0.29678])
t=t.reshape(1,-1)

# %%
lr.predict(t)
# Out:
# array([7.91284999])
