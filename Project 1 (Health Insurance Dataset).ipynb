# %% [markdown]
# # HEALTH INSURANCE DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_health=pd.read_csv('health_insurance')
df_health
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # EDA

# %%
df_health.shape
# Out:
# (1338, 7)

# %%
df_health.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df_health.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [raw]
# There is no null values in the data set.

# %%
df_health.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [raw]
# There is not much difference between mean and 50th percentile so that data is normal distributed.
# Between 75 percentile and max point there is some difference in columns 'bmi' and 'charges' means some outliers are there.

# %%
sns.boxplot(data=df_health)
# Out:
# <Axes: >

# %%
df_health.plot(kind='box',subplots=True,layout=(2,2))
# Out:
# age            Axes(0.125,0.53;0.352273x0.35)
# bmi         Axes(0.547727,0.53;0.352273x0.35)
# children       Axes(0.125,0.11;0.352273x0.35)
# charges     Axes(0.547727,0.11;0.352273x0.35)
# dtype: object

# %%
df_health.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %% [markdown]
# # visualisation

# %%
sns.countplot(x='smoker',data=df_health)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex',data=df_health)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='children',data=df_health)
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x='region',data=df_health)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.distplot(df_health['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df_health['bmi'],kde=True)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df_health['children'],kde=True)
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.distplot(df_health['charges'],kde=True)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %% [markdown]
# # comparing columns with lable(charges)

# %%
plt.bar(df_health['age'], df_health['charges'],label='charges according age')

plt.xlabel('age')
plt.ylabel('charges')
plt.title('Comparison of Two Columns')
plt.legend()

plt.show()

# %%
plt.bar(df_health['bmi'], df_health['charges'],label='charges according bmi')

plt.xlabel('bmi')
plt.ylabel('charges')
plt.title('Comparison of Two Columns')
plt.legend()

plt.show()

# %%
plt.bar(df_health['children'], df_health['charges'],label='charges according children')

plt.xlabel('age')
plt.ylabel('charges')
plt.title('Comparison of Two Columns')
plt.legend()

plt.show()

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

lb=LabelEncoder()

# %%
df_health['region']=lb.fit_transform(df_health['region'])

# %%
df_health['sex']=lb.fit_transform(df_health['sex'])
df_health['smoker']=lb.fit_transform(df_health['smoker'])

# %%
df_health
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
corr=df_health.corr()
corr
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
zs=np.abs(zscore(df_health))
threshold=3
print(np.where(zs>3))
D_F=df_health[(zs<3).all(axis=1)]
D_F
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#         640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#        1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64), array([3, 6, 3, 2, 3, 3, 3, 3, 6, 3, 6, 3, 6, 2, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 6, 6, 3, 3, 6, 2], dtype=int64))
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# ...

# %%
plt.boxplot(D_F['bmi'])
plt.show()

# %%
X=D_F.drop('charges',axis=1)
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1309 rows x 6 columns]

# %%
Y=D_F.iloc[:,-1]
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1309, dtype: float64

# %% [markdown]
# # Spliting data set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.2,random_state=42)

# %%
X_train.shape
# Out:
# (1047, 6)

# %%
X_test.shape
# Out:
# (262, 6)

# %% [markdown]
# # Building Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predi=lr.predict(X_test)

# %%
print(predi,Y_test)
# Out:
# [15572.39344747 12454.76890927 27110.66559012   574.24460932
#   9333.49028991 11665.52619396 10025.67665996 34144.10654457
#  15902.55458752  7452.65768747  6606.10544726  7862.97672683
#   2342.47672552 14797.03760695 11512.20288472 11896.43054843
#  31511.58937141  5876.12583312 11806.25954624  9894.12106735
#   9281.49656911 31156.60976887  8604.66433711 28123.73262576
#   4963.23134567 11536.87811595  4397.34990545 31471.13206944
#   4167.01047185  9654.62297746 17260.310154    5858.8470963
#  28203.06377781  1543.65116766  6403.3455675   6566.95512417
#   5684.14791817 10807.47581869  9312.37540827  7066.12914451
#  33311.82935746 13332.51684168  1822.79194434  9167.18845265
#   2377.03419915 36231.39519177 27622.79560441  8282.56531524
#  -1101.65938011 16878.0939001   6723.05902088 16083.99281429
#   1018.52417865 12434.70112233  8757.42757499 12979.74986778
#   6365.34956244  5489.59729015  9087.51052102 10998.26487828
# ...

# %%
from sklearn import metrics
metrics.r2_score(Y_test,predi)
# Out:
# 0.7783539090730872

# %% [raw]
# model is predicting with 77% accuracy.

# %% [markdown]
# # Predicting System

# %%
t=np.array([37,1,29.83,2,0,2])
t.shape
# Out:
# (6,)

# %%
t=t.reshape(1,-1)
t.shape
# Out:
# (1, 6)

# %%
lr.predict(t)
# Out:
# array([7927.72980831])
